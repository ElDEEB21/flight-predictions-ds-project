# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/processed/flights cleaned.csv')
df
# Out:
#          Airline Departure City Departure Time  Number of Stops  \
# 0       SpiceJet          Delhi        Evening                0
# 1       SpiceJet          Delhi  Early Morning                0
# 2        AirAsia          Delhi  Early Morning                0
# 3        Vistara          Delhi        Morning                0
# 4        Vistara          Delhi        Morning                0
# ...          ...            ...            ...              ...
# 297935   Vistara        Chennai        Morning                1
# 297936   Vistara        Chennai      Afternoon                1
# 297937   Vistara        Chennai  Early Morning                1
# 297938   Vistara        Chennai  Early Morning                1
# 297939   Vistara        Chennai        Morning                1
#
#          Arrival Time Arrival City Flight Class  Flight Duration (hours)  \
# 0               Night       Mumbai      Economy                     2.17
# 1             Morning       Mumbai      Economy                     2.33
# 2       Early Morning       Mumbai      Economy                     2.17
# 3           Afternoon       Mumbai      Economy                     2.25
# 4             Morning       Mumbai      Economy                     2.33
# ...               ...          ...          ...                      ...
# 297935        Evening    Hyderabad     Business                    10.08
# 297936          Night    Hyderabad     Business                    10.42
# 297937          Night    Hyderabad     Business                    13.83
# 297938        Evening    Hyderabad     Business                    10.00
# 297939        Evening    Hyderabad     Business                    10.08
#
#         Days Until Departure  Price (USD)
# 0                          1       71.436
# 1                          1       71.436
# 2                          1       71.472
# 3                          1       71.460
# 4                          1       71.460
# ...                      ...          ...
# 297935                    49      831.180
# 297936                    49      925.260
# 297937                    49      949.188
# 297938                    49      979.020
# 297939                    49      979.020
#
# [297940 rows x 10 columns]

# %%
for col in df.columns[:7]:
    print(col, df[col].unique())
# Out:
# Airline ['SpiceJet' 'AirAsia' 'Vistara' 'GO_FIRST' 'Indigo' 'Air_India']
# Departure City ['Delhi' 'Mumbai' 'Bangalore' 'Kolkata' 'Hyderabad' 'Chennai']
# Departure Time ['Evening' 'Early Morning' 'Morning' 'Afternoon' 'Night' 'Late Night']
# Number of Stops [0 1 2]
# Arrival Time ['Night' 'Morning' 'Early Morning' 'Afternoon' 'Evening' 'Late Night']
# Arrival City ['Mumbai' 'Bangalore' 'Kolkata' 'Hyderabad' 'Chennai' 'Delhi']
# Flight Class ['Economy' 'Business']

# %%
df = pd.get_dummies(df, columns=['Airline', 'Departure City', 'Arrival City', 
                                 'Departure Time', 'Arrival Time', 'Flight Class'], drop_first=True)

# %%
scaler = StandardScaler()
df[['Flight Duration (hours)', 'Days Until Departure']] = scaler.fit_transform(df[['Flight Duration (hours)', 'Days Until Departure']])

# %%
corr = df.corr()
print("Correlation matrix:\n", corr)
# Out:
# Correlation matrix:
#                                Number of Stops  Flight Duration (hours)  \
# Number of Stops                      1.000000                 0.459992
# Flight Duration (hours)              0.459992                 1.000000
# Days Until Departure                -0.009812                -0.039839
# Price (USD)                          0.114772                 0.201035
# Airline_Air_India                    0.053453                 0.274043
# Airline_GO_FIRST                    -0.033025                -0.140172
# Airline_Indigo                      -0.170764                -0.366443
# Airline_SpiceJet                    -0.076345                 0.017228
# Airline_Vistara                      0.099357                 0.132746
# Departure City_Chennai               0.019327                 0.032045
# Departure City_Delhi                -0.046274                -0.046248
# Departure City_Hyderabad             0.007714                 0.000368
# Departure City_Kolkata               0.044045                 0.059117
# Departure City_Mumbai               -0.023700                -0.023508
# Arrival City_Chennai                 0.061684                 0.061549
# Arrival City_Delhi                  -0.102466                -0.114370
# Arrival City_Hyderabad               0.027194                 0.064857
# Arrival City_Kolkata                 0.061106                 0.060504
# Arrival City_Mumbai                 -0.047676                -0.044287
# Departure Time_Early Morning         0.012410                -0.046559
# Departure Time_Evening              -0.038861                 0.106964
# Departure Time_Late Night           -0.036333                -0.045685
# Departure Time_Morning               0.049556                -0.073847
# Departure Time_Night                -0.058904                 0.116581
# Arrival Time_Early Morning          -0.020089                 0.010325
# Arrival Time_Evening                 0.067055                 0.030885
# Arrival Time_Late Night             -0.017303                -0.107515
# Arrival Time_Morning                -0.041872                 0.126466
# Arrival Time_Night                   0.021552                -0.063251
# Flight Class_Economy                 0.003188                -0.136665
#
#                               Days Until Departure  Price (USD)  \
# Number of Stops                          -0.009812     0.114772
# Flight Duration (hours)                  -0.039839     0.201035
# Days Until Departure                      1.000000    -0.092302
# Price (USD)                              -0.092302     1.000000
# Airline_Air_India                        -0.022867     0.067971
# Airline_GO_FIRST                          0.030650    -0.194655
# Airline_Indigo                            0.005908    -0.280275
# Airline_SpiceJet                         -0.017442    -0.112216
# Airline_Vistara                          -0.007635     0.360780
# Departure City_Chennai                    0.002834     0.018701
# Departure City_Delhi                     -0.000962    -0.042051
# Departure City_Hyderabad                  0.010921    -0.013657
# Departure City_Kolkata                    0.000408     0.015227
# Departure City_Mumbai                    -0.009586     0.013266
# Arrival City_Chennai                      0.001130     0.018490
# Arrival City_Delhi                        0.006493    -0.052295
# Arrival City_Hyderabad                   -0.000144    -0.008663
# Arrival City_Kolkata                     -0.004156     0.020148
# Arrival City_Mumbai                      -0.004281     0.011174
# Departure Time_Early Morning              0.004049    -0.011808
# Departure Time_Evening                   -0.010003     0.008018
# Departure Time_Late Night                 0.011744    -0.033997
# Departure Time_Morning                   -0.003616     0.017042
# Departure Time_Night                      0.003682     0.042505
# Arrival Time_Early Morning                0.021164    -0.060703
# Arrival Time_Evening                     -0.014226     0.055912
# Arrival Time_Late Night                   0.026655    -0.093476
# Arrival Time_Morning                     -0.003738     0.031198
# Arrival Time_Night                       -0.004375     0.020780
# Flight Class_Economy                      0.013349    -0.938046
#
#                               Airline_Air_India  Airline_GO_FIRST  \
# Number of Stops                        0.053453         -0.033025
# Flight Duration (hours)                0.274043         -0.140172
# Days Until Departure                  -0.022867          0.030650
# Price (USD)                            0.067971         -0.194655
# Airline_Air_India                      1.000000         -0.176469
# Airline_GO_FIRST                      -0.176469          1.000000
# Airline_Indigo                        -0.248891         -0.117869
# Airline_SpiceJet                      -0.105467         -0.049947
# Airline_Vistara                       -0.526023         -0.249113
# Departure City_Chennai                -0.012261         -0.063064
# Departure City_Delhi                   0.011806          0.029648
# Departure City_Hyderabad               0.000792         -0.023273
# Departure City_Kolkata                -0.003206          0.000823
# Departure City_Mumbai                  0.037290          0.027018
# Arrival City_Chennai                   0.005603         -0.059168
# Arrival City_Delhi                    -0.016447          0.034735
# Arrival City_Hyderabad                 0.009981         -0.025395
# Arrival City_Kolkata                  -0.006380         -0.000229
# Arrival City_Mumbai                    0.042546          0.024052
# Departure Time_Early Morning           0.034122          0.028602
# Departure Time_Evening                 0.020820         -0.002264
# Departure Time_Late Night             -0.007146          0.008694
# Departure Time_Morning                -0.025968         -0.041476
# Departure Time_Night                   0.010833         -0.024579
# Arrival Time_Early Morning            -0.025874          0.086688
# Arrival Time_Evening                  -0.041499         -0.045302
# Arrival Time_Late Night               -0.059869          0.101922
# Arrival Time_Morning                   0.068305         -0.065090
# Arrival Time_Night                    -0.001356          0.001332
# Flight Class_Economy                  -0.123744          0.195005
#
#                               Airline_Indigo  Airline_SpiceJet  \
# Number of Stops                    -0.170764         -0.076345
# Flight Duration (hours)            -0.366443          0.017228
# Days Until Departure                0.005908         -0.017442
# Price (USD)                        -0.280275         -0.112216
# Airline_Air_India                  -0.248891         -0.105467
# Airline_GO_FIRST                   -0.117869         -0.049947
# Airline_Indigo                      1.000000         -0.070445
# Airline_SpiceJet                   -0.070445          1.000000
# Airline_Vistara                    -0.351348         -0.148883
# Departure City_Chennai              0.032109          0.003427
# Departure City_Delhi               -0.012109          0.031085
# Departure City_Hyderabad            0.009415         -0.050786
# Departure City_Kolkata              0.016642          0.031919
# Departure City_Mumbai              -0.028197         -0.004484
# Arrival City_Chennai                0.018145         -0.005832
# Arrival City_Delhi                 -0.003210          0.041324
# Arrival City_Hyderabad             -0.001302         -0.050290
# Arrival City_Kolkata                0.034349          0.030811
# Arrival City_Mumbai                -0.030104         -0.000463
# Departure Time_Early Morning       -0.032268          0.032220
# Departure Time_Evening             -0.021009          0.000899
# Departure Time_Late Night           0.078654         -0.011446
# Departure Time_Morning              0.028989         -0.025092
# Departure Time_Night               -0.073767          0.003810
# Arrival Time_Early Morning          0.014659          0.018704
# Arrival Time_Evening                0.007954         -0.039450
# Arrival Time_Late Night             0.063728          0.001000
# Arrival Time_Morning               -0.083846          0.031202
# Arrival Time_Night                 -0.009776          0.012071
# Flight Class_Economy                0.275034          0.116545
#
#                               Airline_Vistara  Departure City_Chennai  ...  \
# Number of Stops                      0.099357                0.019327  ...
# Flight Duration (hours)              0.132746                0.032045  ...
# Days Until Departure                -0.007635                0.002834  ...
# Price (USD)                          0.360780                0.018701  ...
# Airline_Air_India                   -0.526023               -0.012261  ...
# Airline_GO_FIRST                    -0.249113               -0.063064  ...
# Airline_Indigo                      -0.351348                0.032109  ...
# Airline_SpiceJet                    -0.148883                0.003427  ...
# Airline_Vistara                      1.000000                0.032758  ...
# Departure City_Chennai               0.032758                1.000000  ...
# Departure City_Delhi                -0.047750               -0.194530  ...
# Departure City_Hyderabad             0.029203               -0.153283  ...
# Departure City_Kolkata              -0.026605               -0.165161  ...
# Departure City_Mumbai               -0.007362               -0.194264  ...
# Arrival City_Chennai                 0.028845               -0.151976  ...
# Arrival City_Delhi                  -0.039195                0.060608  ...
# Arrival City_Hyderabad               0.036906                0.015174  ...
# Arrival City_Kolkata                -0.031341                0.016186  ...
# Arrival City_Mumbai                 -0.016232                0.043714  ...
# Departure Time_Early Morning        -0.036387                0.017722  ...
# Departure Time_Evening              -0.006164               -0.072163  ...
# Departure Time_Late Night           -0.057090               -0.014610  ...
# Departure Time_Morning               0.056994                0.032320  ...
# Departure Time_Night                 0.044373                0.036279  ...
# Arrival Time_Early Morning          -0.058118               -0.017448  ...
# Arrival Time_Evening                 0.091626                0.016676  ...
# Arrival Time_Late Night             -0.134472                0.009086  ...
# Arrival Time_Morning                 0.029914               -0.022783  ...
# Arrival Time_Night                   0.024508                0.003544  ...
# Flight Class_Economy                -0.301206               -0.010419  ...
#
#                               Departure Time_Evening  \
# Number of Stops                            -0.038861
# Flight Duration (hours)                     0.106964
# Days Until Departure                       -0.010003
# Price (USD)                                 0.008018
# Airline_Air_India                           0.020820
# Airline_GO_FIRST                           -0.002264
# Airline_Indigo                             -0.021009
# Airline_SpiceJet                            0.000899
# Airline_Vistara                            -0.006164
# Departure City_Chennai                     -0.072163
# Departure City_Delhi                        0.069713
# Departure City_Hyderabad                   -0.067679
# Departure City_Kolkata                     -0.009730
# Departure City_Mumbai                      -0.002138
# Arrival City_Chennai                        0.020382
# Arrival City_Delhi                         -0.023330
# Arrival City_Hyderabad                      0.015076
# Arrival City_Kolkata                        0.022689
# Arrival City_Mumbai                        -0.010139
# Departure Time_Early Morning               -0.280881
# Departure Time_Evening                      1.000000
# Departure Time_Late Night                  -0.034800
# Departure Time_Morning                     -0.293325
# Departure Time_Night                       -0.229191
# Arrival Time_Early Morning                  0.047429
# Arrival Time_Evening                       -0.072329
# Arrival Time_Late Night                     0.102027
# Arrival Time_Morning                        0.081395
# Arrival Time_Night                         -0.022288
# Flight Class_Economy                       -0.010091
#
#                               Departure Time_Late Night  \
# Number of Stops                               -0.036333
# Flight Duration (hours)                       -0.045685
# Days Until Departure                           0.011744
# Price (USD)                                   -0.033997
# Airline_Air_India                             -0.007146
# Airline_GO_FIRST                               0.008694
# Airline_Indigo                                 0.078654
# Airline_SpiceJet                              -0.011446
# Airline_Vistara                               -0.057090
# Departure City_Chennai                        -0.014610
# Departure City_Delhi                           0.011709
# Departure City_Hyderabad                      -0.020724
# Departure City_Kolkata                        -0.012376
# Departure City_Mumbai                          0.000525
# Arrival City_Chennai                          -0.008090
# Arrival City_Delhi                             0.015810
# Arrival City_Hyderabad                        -0.017302
# Arrival City_Kolkata                           0.021239
# Arrival City_Mumbai                           -0.003260
# Departure Time_Early Morning                  -0.035427
# Departure Time_Evening                        -0.034800
# Departure Time_Late Night                      1.000000
# Departure Time_Morning                        -0.036996
# Departure Time_Night                          -0.028907
# Arrival Time_Early Morning                     0.099951
# Arrival Time_Evening                          -0.028558
# Arrival Time_Late Night                        0.017515
# Arrival Time_Morning                           0.015516
# Arrival Time_Night                            -0.032112
# Flight Class_Economy                           0.029543
#
#                               Departure Time_Morning  Departure Time_Night  \
# Number of Stops                             0.049556             -0.058904
# Flight Duration (hours)                    -0.073847              0.116581
# Days Until Departure                       -0.003616              0.003682
# Price (USD)                                 0.017042              0.042505
# Airline_Air_India                          -0.025968              0.010833
# Airline_GO_FIRST                           -0.041476             -0.024579
# Airline_Indigo                              0.028989             -0.073767
# Airline_SpiceJet                           -0.025092              0.003810
# Airline_Vistara                             0.056994              0.044373
# Departure City_Chennai                      0.032320              0.036279
# Departure City_Delhi                       -0.016365             -0.061925
# Departure City_Hyderabad                    0.005330              0.068787
# Departure City_Kolkata                      0.022890              0.028667
# Departure City_Mumbai                      -0.035495             -0.006436
# Arrival City_Chennai                       -0.002534             -0.008353
# Arrival City_Delhi                          0.024659              0.002422
# Arrival City_Hyderabad                      0.000776              0.002734
# Arrival City_Kolkata                       -0.020256             -0.001828
# Arrival City_Mumbai                        -0.008873              0.002101
# Departure Time_Early Morning               -0.298611             -0.233321
# Departure Time_Evening                     -0.293325             -0.229191
# Departure Time_Late Night                  -0.036996             -0.028907
# Departure Time_Morning                      1.000000             -0.243658
# Departure Time_Night                       -0.243658              1.000000
# Arrival Time_Early Morning                 -0.071047              0.073221
# Arrival Time_Evening                        0.100993             -0.067904
# Arrival Time_Late Night                    -0.071250              0.027432
# Arrival Time_Morning                       -0.105045              0.137313
# Arrival Time_Night                          0.036129             -0.097940
# Flight Class_Economy                       -0.001848             -0.050630
#
#                               Arrival Time_Early Morning  \
# Number of Stops                                -0.020089
# Flight Duration (hours)                         0.010325
# Days Until Departure                            0.021164
# Price (USD)                                    -0.060703
# Airline_Air_India                              -0.025874
# Airline_GO_FIRST                                0.086688
# Airline_Indigo                                  0.014659
# Airline_SpiceJet                                0.018704
# Airline_Vistara                                -0.058118
# Departure City_Chennai                         -0.017448
# Departure City_Delhi                            0.080165
# Departure City_Hyderabad                       -0.022946
# Departure City_Kolkata                         -0.009384
# Departure City_Mumbai                          -0.055526
# Arrival City_Chennai                            0.060488
# Arrival City_Delhi                             -0.092365
# Arrival City_Hyderabad                          0.070237
# Arrival City_Kolkata                           -0.006387
# Arrival City_Mumbai                             0.013352
# Departure Time_Early Morning                   -0.010209
# Departure Time_Evening                          0.047429
# Departure Time_Late Night                       0.099951
# Departure Time_Morning                         -0.071047
# Departure Time_Night                            0.073221
# Arrival Time_Early Morning                      1.000000
# Arrival Time_Evening                           -0.138665
# Arrival Time_Late Night                        -0.051432
# Arrival Time_Morning                           -0.119469
# Arrival Time_Night                             -0.154110
# Flight Class_Economy                            0.041976
#
#                               Arrival Time_Evening  Arrival Time_Late Night  \
# Number of Stops                           0.067055                -0.017303
# Flight Duration (hours)                   0.030885                -0.107515
# Days Until Departure                     -0.014226                 0.026655
# Price (USD)                               0.055912                -0.093476
# Airline_Air_India                        -0.041499                -0.059869
# Airline_GO_FIRST                         -0.045302                 0.101922
# Airline_Indigo                            0.007954                 0.063728
# Airline_SpiceJet                         -0.039450                 0.001000
# Airline_Vistara                           0.091626                -0.134472
# Departure City_Chennai                    0.016676                 0.009086
# Departure City_Delhi                     -0.026407                -0.028454
# Departure City_Hyderabad                 -0.003507                 0.008991
# Departure City_Kolkata                   -0.017089                 0.010141
# Departure City_Mumbai                     0.012562                -0.006065
# Arrival City_Chennai                     -0.026742                -0.041733
# Arrival City_Delhi                       -0.018360                 0.146914
# Arrival City_Hyderabad                   -0.014466                -0.064853
# Arrival City_Kolkata                      0.101853                -0.046470
# Arrival City_Mumbai                      -0.053207                -0.038940
# Departure Time_Early Morning              0.027964                -0.087404
# Departure Time_Evening                   -0.072329                 0.102027
# Departure Time_Late Night                -0.028558                 0.017515
# Departure Time_Morning                    0.100993                -0.071250
# Departure Time_Night                     -0.067904                 0.027432
# Arrival Time_Early Morning               -0.138665                -0.051432
# Arrival Time_Evening                      1.000000                -0.131449
# Arrival Time_Late Night                  -0.131449                 1.000000
# Arrival Time_Morning                     -0.305336                -0.113252
# Arrival Time_Night                       -0.393870                -0.146090
# Flight Class_Economy                     -0.032844                 0.085916
#
#                               Arrival Time_Morning  Arrival Time_Night  \
# Number of Stops                          -0.041872            0.021552
# Flight Duration (hours)                   0.126466           -0.063251
# Days Until Departure                     -0.003738           -0.004375
# Price (USD)                               0.031198            0.020780
# Airline_Air_India                         0.068305           -0.001356
# Airline_GO_FIRST                         -0.065090            0.001332
# Airline_Indigo                           -0.083846           -0.009776
# Airline_SpiceJet                          0.031202            0.012071
# Airline_Vistara                           0.029914            0.024508
# Departure City_Chennai                   -0.022783            0.003544
# Departure City_Delhi                      0.002037           -0.007181
# Departure City_Hyderabad                  0.009056            0.010493
# Departure City_Kolkata                   -0.000861            0.016408
# Departure City_Mumbai                     0.020987            0.008166
# Arrival City_Chennai                      0.054848            0.018403
# Arrival City_Delhi                       -0.034847           -0.028772
# Arrival City_Hyderabad                   -0.032925            0.020482
# Arrival City_Kolkata                      0.035046           -0.089341
# Arrival City_Mumbai                      -0.028761            0.069607
# Departure Time_Early Morning             -0.017518           -0.035286
# Departure Time_Evening                    0.081395           -0.022288
# Departure Time_Late Night                 0.015516           -0.032112
# Departure Time_Morning                   -0.105045            0.036129
# Departure Time_Night                      0.137313           -0.097940
# Arrival Time_Early Morning               -0.119469           -0.154110
# Arrival Time_Evening                     -0.305336           -0.393870
# Arrival Time_Late Night                  -0.113252           -0.146090
# Arrival Time_Morning                      1.000000           -0.339345
# Arrival Time_Night                       -0.339345            1.000000
# Flight Class_Economy                     -0.040208           -0.007759
#
#                               Flight Class_Economy
# Number of Stops                           0.003188
# Flight Duration (hours)                  -0.136665
# Days Until Departure                      0.013349
# Price (USD)                              -0.938046
# Airline_Air_India                        -0.123744
# Airline_GO_FIRST                          0.195005
# Airline_Indigo                            0.275034
# Airline_SpiceJet                          0.116545
# Airline_Vistara                          -0.301206
# Departure City_Chennai                   -0.010419
# Departure City_Delhi                      0.013586
# Departure City_Hyderabad                 -0.002970
# Departure City_Kolkata                    0.019741
# Departure City_Mumbai                    -0.016306
# Arrival City_Chennai                     -0.012067
# Arrival City_Delhi                        0.021309
# Arrival City_Hyderabad                   -0.007512
# Arrival City_Kolkata                      0.013505
# Arrival City_Mumbai                      -0.011539
# Departure Time_Early Morning              0.011769
# Departure Time_Evening                   -0.010091
# Departure Time_Late Night                 0.029543
# Departure Time_Morning                   -0.001848
# Departure Time_Night                     -0.050630
# Arrival Time_Early Morning                0.041976
# Arrival Time_Evening                     -0.032844
# Arrival Time_Late Night                   0.085916
# Arrival Time_Morning                     -0.040208
# Arrival Time_Night                       -0.007759
# Flight Class_Economy                      1.000000
#
# [30 rows x 30 columns]

# %%
x = df.drop(columns=['Price (USD)'])
y = df['Price (USD)']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((238352, 29), (59588, 29), (238352,), (59588,))

# %%
x_train.to_csv('../data/processed/x_train_processed.csv', index=False)
x_test.to_csv('../data/processed/x_test_processed.csv', index=False)
y_train.to_csv('../data/processed/y_train.csv', index=False)
y_test.to_csv('../data/processed/y_test.csv', index=False)
